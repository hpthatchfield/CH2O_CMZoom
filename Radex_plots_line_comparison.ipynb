# %%
import astropy.io.fits
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, hstack, Column
import pandas as pd
# %matplotlib notebook

# %%
H2_density1, pH2_density1, oH2_density1, LINE1, E_UP1, FREQ1, WAVEL1, T_EX1, TAU1, T_R1, POP_up1, POP_low1, FLUX_Kkms1, FLUX_ergcm2s1 = np.genfromtxt('p-h2co_1', unpack=True, dtype=str)
H2_density2, pH2_density2, oH2_density2, LINE2, E_UP2, FREQ2, WAVEL2, T_EX2, TAU2, T_R2, POP_up2, POP_low2, FLUX_Kkms2, FLUX_ergcm2s2 = np.genfromtxt('p-h2co_2', unpack=True, dtype=str)
H2_density3, pH2_density3, oH2_density3, LINE3, E_UP3, FREQ3, WAVEL3, T_EX3, TAU3, T_R3, POP_up3, POP_low3, FLUX_Kkms3, FLUX_ergcm2s3 = np.genfromtxt('p-h2co_3', unpack=True, dtype=str)
H2_density4, pH2_density4, oH2_density4, LINE4, E_UP4, FREQ4, WAVEL4, T_EX4, TAU4, T_R4, POP_up4, POP_low4, FLUX_Kkms4, FLUX_ergcm2s4 = np.genfromtxt('p-h2co_4', unpack=True, dtype=str)
H2_density5, pH2_density5, oH2_density5, LINE5, E_UP5, FREQ5, WAVEL5, T_EX5, TAU5, T_R5, POP_up5, POP_low5, FLUX_Kkms5, FLUX_ergcm2s5 = np.genfromtxt('p-h2co_5', unpack=True, dtype=str)
H2_density6, pH2_density6, oH2_density6, LINE6, E_UP6, FREQ6, WAVEL6, T_EX6, TAU6, T_R6, POP_up6, POP_low6, FLUX_Kkms6, FLUX_ergcm2s6 = np.genfromtxt('p-h2co_6', unpack=True, dtype=str)
H2_density7, pH2_density7, oH2_density7, LINE7, E_UP7, FREQ7, WAVEL7, T_EX7, TAU7, T_R7, POP_up7, POP_low7, FLUX_Kkms7, FLUX_ergcm2s7 = np.genfromtxt('p-h2co_7', unpack=True, dtype=str)
H2_density8, pH2_density8, oH2_density8, LINE8, E_UP8, FREQ8, WAVEL8, T_EX8, TAU8, T_R8, POP_up8, POP_low8, FLUX_Kkms8, FLUX_ergcm2s8 = np.genfromtxt('p-h2co_8', unpack=True, dtype=str)
H2_density9, pH2_density9, oH2_density9, LINE9, E_UP9, FREQ9, WAVEL9, T_EX9, TAU9, T_R9, POP_up9, POP_low9, FLUX_Kkms9, FLUX_ergcm2s9 = np.genfromtxt('p-h2co_9', unpack=True, dtype=str)

specific_condition1_1 = (LINE1 == '3_0_3-2_0_2')
specific_condition1_2 = (LINE1 == '3_2_2-2_2_1')
specific_condition1_3 = (LINE1 == '3_2_1-2_2_0')
H2_density1 = np.array(H2_density1, dtype=float)
T_EX1 = np.array(T_EX1, dtype=float)
T_R1 = np.array(T_R1, dtype=float)
TR_ratio1 = T_R1[specific_condition1_3]/T_R1[specific_condition1_1]

specific_condition2_1 = (LINE2 == '3_0_3-2_0_2')
specific_condition2_2 = (LINE2 == '3_2_2-2_2_1')
specific_condition2_3 = (LINE2 == '3_2_1-2_2_0')
H2_density2 = np.array(H2_density2, dtype=float)
T_EX2 = np.array(T_EX2, dtype=float)
T_R2 = np.array(T_R2, dtype=float)
TR_ratio2 = T_R2[specific_condition2_3]/T_R2[specific_condition2_1]

specific_condition3_1 = (LINE3 == '3_0_3-2_0_2')
specific_condition3_2 = (LINE3 == '3_2_2-2_2_1')
specific_condition3_3 = (LINE3 == '3_2_1-2_2_0')
H2_density3 = np.array(H2_density3, dtype=float)
T_EX3 = np.array(T_EX3, dtype=float)
T_R3 = np.array(T_R3, dtype=float)
TR_ratio3 = T_R3[specific_condition3_3]/T_R3[specific_condition3_1]


specific_condition4_1 = (LINE4 == '3_0_3-2_0_2')
specific_condition4_2 = (LINE4 == '3_2_2-2_2_1')
specific_condition4_3 = (LINE4 == '3_2_1-2_2_0')
H2_density4 = np.array(H2_density4, dtype=float)
T_EX4 = np.array(T_EX4, dtype=float)
T_R4 = np.array(T_R4, dtype=float)
TR_ratio4 = T_R4[specific_condition4_3]/T_R4[specific_condition4_1]

specific_condition5_1 = (LINE5 == '3_0_3-2_0_2')
specific_condition5_2 = (LINE5 == '3_2_2-2_2_1')
specific_condition5_3 = (LINE5 == '3_2_1-2_2_0')
H2_density5 = np.array(H2_density5, dtype=float)
T_EX5 = np.array(T_EX5, dtype=float)
T_R5 = np.array(T_R5, dtype=float)
TR_ratio5 = T_R5[specific_condition5_3]/T_R5[specific_condition5_1]

specific_condition6_1 = (LINE6 == '3_0_3-2_0_2')
specific_condition6_2 = (LINE6 == '3_2_2-2_2_1')
specific_condition6_3 = (LINE6 == '3_2_1-2_2_0')
H2_density6 = np.array(H2_density6, dtype=float)
T_EX6 = np.array(T_EX6, dtype=float)
T_R6 = np.array(T_R6, dtype=float)
TR_ratio6 = T_R6[specific_condition6_3]/T_R6[specific_condition6_1]

specific_condition7_1 = (LINE7 == '3_0_3-2_0_2')
specific_condition7_2 = (LINE7 == '3_2_2-2_2_1')
specific_condition7_3 = (LINE7 == '3_2_1-2_2_0')
H2_density7 = np.array(H2_density7, dtype=float)
T_EX7 = np.array(T_EX7, dtype=float)
T_R7 = np.array(T_R7, dtype=float)
TR_ratio7 = T_R7[specific_condition7_3]/T_R7[specific_condition7_1]

specific_condition8_1 = (LINE8 == '3_0_3-2_0_2')
specific_condition8_2 = (LINE8 == '3_2_2-2_2_1')
specific_condition8_3 = (LINE8 == '3_2_1-2_2_0')
H2_density8 = np.array(H2_density8, dtype=float)
T_EX8 = np.array(T_EX8, dtype=float)
T_R8 = np.array(T_R8, dtype=float)
TR_ratio8 = T_R8[specific_condition8_3]/T_R8[specific_condition8_1]

specific_condition9_1 = (LINE9 == '3_0_3-2_0_2')
specific_condition9_2 = (LINE9 == '3_2_2-2_2_1')
specific_condition9_3 = (LINE9 == '3_2_1-2_2_0')
H2_density9 = np.array(H2_density9, dtype=float)
T_EX9 = np.array(T_EX9, dtype=float)
T_R9 = np.array(T_R9, dtype=float)
TR_ratio9 = T_R9[specific_condition9_3]/T_R9[specific_condition9_1]

# %% [markdown]
# ## Plots for each line- Excitation temperature vs H2 density

# %%
#303-202
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(7,7))
ax.scatter(H2_density1[specific_condition1_1],T_EX1[specific_condition1_1], c='darkorange', marker='x', label='file 1 (Tkin=100, N=1e14, 1e15)')
ax.scatter(H2_density2[specific_condition2_1],T_EX2[specific_condition2_1], c='limegreen', marker='v', label='file 2 (Tkin=100, N=1e13)')
ax.scatter(H2_density3[specific_condition3_1],T_EX3[specific_condition3_1], c='dodgerblue', marker='+', label='file 3 (Tkin=100, N=1e14)')
ax.scatter(H2_density4[specific_condition4_1],T_EX4[specific_condition4_1], c='deeppink', marker='o', label='file 4 (Tkin=200, N=1e14)')
ax.scatter(H2_density5[specific_condition5_1],T_EX5[specific_condition5_1], c='darkorchid', marker='d', label='file 5 (Tkin=200, N=1e13)')
ax.scatter(H2_density6[specific_condition6_1],T_EX6[specific_condition6_1], c='gold', marker='h', label='file 6 (Tkin=400, N=1e13)')
ax.scatter(H2_density7[specific_condition7_1],T_EX7[specific_condition7_1], c='black', marker='1', label='file 7 (Tkin=50, N=1e13)')
ax.scatter(H2_density8[specific_condition8_1],T_EX8[specific_condition8_1], c='darkred', marker='*', label='file 8 (Tkin=100, N=1e13)')
ax.scatter(H2_density9[specific_condition9_1],T_EX9[specific_condition9_1], c='blue', marker='^', label='file 9 (Tkin=200, N=1e13)')


plt.title("303-202 line: Excitation temperature")
plt.ylabel('Excitation temperature (K)')
plt.xlabel('H2 density (cm*-3)')
plt.show()
ax.legend(loc='best')

ax.set_xscale('log')
#ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
#322-221
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(7,7))
ax.scatter(H2_density1[specific_condition1_2],T_EX1[specific_condition1_2], c='darkorange', marker='x', label='file 1 (Tkin=100, N=1e14, 1e15)')
ax.scatter(H2_density2[specific_condition2_2],T_EX2[specific_condition2_2], c='limegreen', marker='v', label='file 2 (Tkin=100, N=1e13)')
ax.scatter(H2_density3[specific_condition3_2],T_EX3[specific_condition3_2], c='dodgerblue', marker='+', label='file 3 (Tkin=100, N=1e14)')
ax.scatter(H2_density4[specific_condition4_2],T_EX4[specific_condition4_2], c='deeppink', marker='o', label='file 4 (Tkin=200, N=1e14)')
ax.scatter(H2_density5[specific_condition5_2],T_EX5[specific_condition5_2], c='darkorchid', marker='d', label='file 5 (Tkin=200, N=1e13)')
ax.scatter(H2_density6[specific_condition6_2],T_EX6[specific_condition6_2], c='gold', marker='h', label='file 6 (Tkin=400, N=1e13)')
ax.scatter(H2_density7[specific_condition7_2],T_EX7[specific_condition7_2], c='black', marker='1', label='file 7 (Tkin=50, N=1e13)')
ax.scatter(H2_density8[specific_condition8_2],T_EX8[specific_condition8_2], c='darkred', marker='*', label='file 8 (Tkin=100, N=1e13)')
ax.scatter(H2_density9[specific_condition9_2],T_EX9[specific_condition9_2], c='blue', marker='^', label='file 9 (Tkin=200, N=1e13)')



plt.title("322-221 line: Excitation Temperature")
plt.ylabel('Excitation temperature (K)')
plt.xlabel('H2 density (cm*-3)')
plt.show()
ax.legend(loc='best')

ax.set_xscale('log')
#ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
#321-220
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(7,7))
ax.scatter(H2_density1[specific_condition1_3],T_EX1[specific_condition1_3], c='darkorange', marker='x', label='file 1 (Tkin=100, N=1e14, 1e15)')
ax.scatter(H2_density2[specific_condition2_3],T_EX2[specific_condition2_3], c='limegreen', marker='v', label='file 2 (Tkin=100, N=1e13)')
ax.scatter(H2_density3[specific_condition3_3],T_EX3[specific_condition3_3], c='dodgerblue', marker='+', label='file 3 (Tkin=100, N=1e14)')
ax.scatter(H2_density4[specific_condition4_3],T_EX4[specific_condition4_3], c='deeppink', marker='o', label='file 4 (Tkin=200, N=1e14)')
ax.scatter(H2_density5[specific_condition5_3],T_EX5[specific_condition5_3], c='darkorchid', marker='d', label='file 5 (Tkin=200, N=1e13)')
ax.scatter(H2_density6[specific_condition6_3],T_EX6[specific_condition6_3], c='gold', marker='h', label='file 6 (Tkin=400, N=1e13)')
ax.scatter(H2_density7[specific_condition7_3],T_EX7[specific_condition7_3], c='black', marker='1', label='file 7 (Tkin=50, N=1e13)')
ax.scatter(H2_density8[specific_condition8_3],T_EX8[specific_condition8_3], c='darkred', marker='*', label='file 8 (Tkin=100, N=1e13)')
ax.scatter(H2_density9[specific_condition9_3],T_EX9[specific_condition9_3], c='blue', marker='^', label='file 9 (Tkin=200, N=1e13)')




plt.title("321-220 line: Excitation temperature")
plt.ylabel('Excitation temperature (K)')
plt.xlabel('H2 density (cm*-3)')
plt.show()
ax.legend(loc='best')

ax.set_xscale('log')
#ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ## Plots for each line: Radiation Temperature

# %%
#303-202
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(7,7))
#ax.scatter(H2_density1[specific_condition1_1],T_R1[specific_condition1_1], c='black', marker='x', label='file 1 (Tkin=100, N=1e14, 1e15)', zorder = 1000)
ax.scatter(H2_density2[specific_condition2_1],T_R2[specific_condition2_1], c='limegreen', marker='v', label='file 2 (Tkin=100, N=1e13)')
ax.scatter(H2_density3[specific_condition3_1],T_R3[specific_condition3_1], c='dodgerblue', marker='+', label='file 3 (Tkin=100, N=1e14)')
ax.scatter(H2_density4[specific_condition4_1],T_R4[specific_condition4_1], c='deeppink', marker='o', label='file 4 (Tkin=200, N=1e14)')
ax.scatter(H2_density5[specific_condition5_1],T_R5[specific_condition5_1], c='darkorchid', marker='d', label='file 5 (Tkin=200, N=1e13)')
ax.scatter(H2_density6[specific_condition6_1],T_R6[specific_condition6_1], c='gold', marker='h', label='file 6 (Tkin=400, N=1e13)')
ax.scatter(H2_density7[specific_condition7_1],T_R7[specific_condition7_1], c='black', marker='1', label='file 7 (Tkin=50, N=1e13)')
ax.scatter(H2_density8[specific_condition8_1],T_R8[specific_condition8_1], c='darkred', marker='*', label='file 8 (Tkin=100, N=1e13)')
ax.scatter(H2_density9[specific_condition9_1],T_R9[specific_condition9_1], c='blue', marker='^', label='file 9 (Tkin=200, N=1e13)')




plt.title("303-202 line: Radiation temperature")
plt.ylabel('Radiation temperature (K)')
plt.xlabel('H2 density (cm*-3)')
plt.show()
ax.legend(loc='best')

ax.set_xscale('log')
# ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
#322-221
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(7,7))
#ax.scatter(H2_density1[specific_condition1_2],T_R1[specific_condition1_2], c='darkorange', marker='x', label='file 1 (Tkin=100, N=1e14, 1e15)')
ax.scatter(H2_density2[specific_condition2_2],T_R2[specific_condition2_2], c='limegreen', marker='v', label='file 2 (Tkin=100, N=1e13)')
ax.scatter(H2_density3[specific_condition3_2],T_R3[specific_condition3_2], c='dodgerblue', marker='+', label='file 3 (Tkin=100, N=1e14)')
ax.scatter(H2_density4[specific_condition4_2],T_R4[specific_condition4_2], c='deeppink', marker='o', label='file 4 (Tkin=200, N=1e14)')
ax.scatter(H2_density5[specific_condition5_2],T_R5[specific_condition5_2], c='darkorchid', marker='d', label='file 5 (Tkin=200, N=1e13)')
ax.scatter(H2_density6[specific_condition6_2],T_R6[specific_condition6_2], c='gold', marker='h', label='file 6 (Tkin=400, N=1e13)')
ax.scatter(H2_density7[specific_condition7_2],T_R7[specific_condition7_2], c='black', marker='1', label='file 7 (Tkin=50, N=1e13)')
ax.scatter(H2_density8[specific_condition8_2],T_R8[specific_condition8_2], c='darkred', marker='*', label='file 8 (Tkin=100, N=1e13)')
ax.scatter(H2_density9[specific_condition9_2],T_R9[specific_condition9_2], c='blue', marker='^', label='file 9 (Tkin=200, N=1e13)')



plt.title("322-221 line: Radiation Temperature")
plt.ylabel('Radiation temperature (K)')
plt.xlabel('H2 density (cm*-3)')
plt.show()
ax.legend(loc='best')

ax.set_xscale('log')
#ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
#321-220
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(7,7))
#ax.scatter(H2_density1[specific_condition1_3],T_R1[specific_condition1_3], c='darkorange', marker='x', label='file 1 (Tkin=100, N=1e14, 1e15)')
ax.scatter(H2_density2[specific_condition2_3],T_R2[specific_condition2_3], c='limegreen', marker='v', label='file 2 (Tkin=100, N=1e13)')
ax.scatter(H2_density3[specific_condition3_3],T_R3[specific_condition3_3], c='dodgerblue', marker='+', label='file 3 (Tkin=100, N=1e14)')
ax.scatter(H2_density4[specific_condition4_3],T_R4[specific_condition4_3], c='deeppink', marker='o', label='file 4 (Tkin=200, N=1e14)')
ax.scatter(H2_density5[specific_condition5_3],T_R5[specific_condition5_3], c='darkorchid', marker='d', label='file 5 (Tkin=200, N=1e13)')
ax.scatter(H2_density6[specific_condition6_3],T_R6[specific_condition6_3], c='gold', marker='h', label='file 6 (Tkin=400, N=1e13)')
ax.scatter(H2_density7[specific_condition7_3],T_R7[specific_condition7_3], c='black', marker='1', label='file 7 (Tkin=50, N=1e13)')
ax.scatter(H2_density8[specific_condition8_3],T_R8[specific_condition8_3], c='darkred', marker='*', label='file 8 (Tkin=100, N=1e13)')
ax.scatter(H2_density9[specific_condition9_3],T_R9[specific_condition9_3], c='blue', marker='^', label='file 9 (Tkin=200, N=1e13)')



plt.title("321-220 line: Radiation temperature")
plt.ylabel('Radiation temperature (K)')
plt.xlabel('H2 density (cm*-3)')
plt.show()
ax.legend(loc='best')

ax.set_xscale('log')
#ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ## Comparison: Ratio of 321-220 rad temp to 303-202 rad temp

# %%
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(7,7))
#ax.scatter(H2_density1[specific_condition1_1],TR_ratio1, c='darkorange', marker='x', label='file 1 (Tkin=100, N=1e14, 1e15)')
ax.scatter(H2_density2[specific_condition2_1],TR_ratio2, c='limegreen', marker='v', label='file 2 (Tkin=100, N=1e13)')
ax.scatter(H2_density3[specific_condition3_1],TR_ratio3, c='dodgerblue', marker='+', label='file 3 (Tkin=100, N=1e14)')
ax.scatter(H2_density4[specific_condition4_1],TR_ratio4, c='deeppink', marker='o', label='file 4 (Tkin=200, N=1e14)')
ax.scatter(H2_density5[specific_condition5_1],TR_ratio5, c='darkorchid', marker='d', label='file 5 (Tkin=200, N=1e13)')
ax.scatter(H2_density6[specific_condition6_1],TR_ratio6, c='gold', marker='h', label='file 6 (Tkin=400, N=1e13)')
ax.scatter(H2_density7[specific_condition7_1],TR_ratio7, c='black', marker='1', label='file 7 (Tkin=50, N=1e13)')
ax.scatter(H2_density8[specific_condition8_1],TR_ratio8, c='darkred', marker='*', label='file 8 (Tkin=100, N=1e13)')
ax.scatter(H2_density9[specific_condition9_1],TR_ratio9, c='blue', marker='^', label='file 9 (Tkin=200, N=1e13)')



plt.title("Ratio of 321-220 rad temp to 303-202 rad temp")
plt.ylabel('Radiation temperature ratio')
plt.xlabel('H2 density (cm*-3)')
plt.show()
ax.legend(loc='best')

ax.set_xscale('log')
#ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="700">
